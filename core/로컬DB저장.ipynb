# %%
import json
import argparse
from dotenv import load_dotenv
from dataclasses import dataclass

load_dotenv()
# Out:
# True

# %%
@dataclass(frozen=True)

# %%
def load_db_confg_from_env() -> DBConfig:

# %%
def main():
    parse=argparse.ArgumentParse(
        
    )
    print(a)

# %%
if __name__=="__main__":
    main()
# Out:
# b
