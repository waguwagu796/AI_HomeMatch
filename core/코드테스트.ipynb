# %%
from __future__ import annotations

import json
import os
from pathlib import Path
from typing import Any, Dict, List

import pymysql
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
JSON_DIR=Path("json")

# %%
def load_json_array(path: Path) -> List[Dict[str, Any]]:
    raw = path.read_text(encoding="utf-8").strip()
    data = json.loads(raw)

    if not isinstance(data, list):
        raise RuntimeError(f"{path.name} : JSON 배열이 아님")

    return data

# %%
def main():
    files = sorted(JSON_DIR.glob("*.txt"))
    if not files:
        raise RuntimeError("json/ 디렉토리에 txt 파일이 없습니다")

    try:
        for file in files:
            print(f"[LOAD] {file.name}")
            
            data = load_json_array(file)
            
    finally:
        return

# %%
files = sorted(JSON_DIR.glob("*.txt"))

# %%
files[3]
# Out:
# WindowsPath('json/2025_분쟁조정사례집_json.txt')

# %%
a= load_json_array(files[2])

# %%
a
# Out:
# [{'source_year': '2023',
#   'source_name': '2023년 주택·상가건물 임대차분쟁조정사례집',
#   'source_doc': '2023_주택상가건물임대차분쟁조정사례집.pdf',
#   'page_start': '24',
#   'page_end': '25',
#   'title': '월차임의 증액 청구',
#   'facts': '1. 신청인(임차인)과 피신청인(임대인)은 목적주택에 관하여 보증금 100,000,000원, 월차임 500,000원, 임대차기간 2020. O. O.부터 2022. O. O.까지로 정하여 임대차계약을 체결함.\n2. 신청인의 계약갱신요구권 행사에 대하여 피신청인은 갱신에 동의하였으나, 차임의 증가 범위에 대한 이견이 있어 분쟁이 발생함.',
#   'issues': '갱신요구권 행사에 따른 갱신 시 차임 증액 상한',
#   'related_rules': '주택임대차보호법 제6조의3(계약갱신 요구 등)\n③ 갱신되는 임대차는 전 임대차와 동일한 조건으로 다시 계약된 것으로 본다. 다만, 차임과 보증금은 제7조의 범위에서 증감할 수 있다.',
#   'related_precedents': None,
#   'result': '보증금 및 차임을 각 5% 증액하되, 신청인이 피신청인에게 월차임 24개월분인 12,600,000원(525,000원×24개월)을 일시에 지급하고, 피신청인이 후속 임대차계약이나 매매계약 체결을 진행하는 경우 협조하기로 함.',
#   'order_text': '신청인과 피신청인이 이 사건 주택에 관하여 2020. O. O.체결한 임대차계약의 기간을 신청인의 갱신요구권 행사에 따라 2024. O. O.까지로 연장한다.\n제1항의 임대차계약의 보증금을 2022. O. O.부터 105,000,000원으로 하며, 신청인은 증액된 보증금 5,000,000원을 2022. O. O.까지 피신청인에게 지급한다.\n제1항의 임대차계약의 월차임을 2022. O. O.부터 525,000원으로 하며, 신청인은 24개월분의 월차임 12,600,000원(525,000원×24)을 2022. O. O.까지 피신청인에게 지급한다.\n신청인이 2024. O. O. 혹은 그 이전에 제1항 기재 주택에서 퇴거하려는 경우, 그 희망일로부터 3개월 전에 피신청인에게 이러한 사실을 고지한다.\n신청인은 제1항 기재 주택에 관한 매매계약 또는 후속 임대차계약 체결을 위해 피신청인의 요구가 있는 경우 위 주택을 피신청인이 지정하는 사람에게 보여주는 데 적극 협조한다. 이 때 방문 일시는 신청인과 피신청인의 상호 협의하에 정한다.\n신청인은 주택임대차보호법 제26조 제4항에 따라 위 제2항, 제3항에 기재된 사항에 대하여 강제집행할 수 있음을 승낙한다.'},
#  {'source_year': '2023',
#   'source_name': '2023년 주택·상가건물 임대차분쟁조정사례집',
#   'source_doc': '2023_주택상가건물임대차분쟁조정사례집.pdf',
#   'page_start': '26',
#   'page_end': '27',
#   'title': '재계약 또는 기간연장의 합의인지의 여부',
#   'facts': '1. 임차인은 신청인인 기존 임대인과 이 사건 주택에 관하여 임대차계약을 체결함.\n2. 임대차기간 중 임대인(현재 임대인)은 신청인으로부터 이 사건 주택을 매수하여 임대인의 지위를 승계함.\n3. 기존 임대차 기간 만료 후 임차인과 임대인은 임대차 기간을 1년으로 하는 계약(이하 ‘이 사건 계약’이라 함)을 하였음.\n4. 임차인은 위 계약의 임대차 기간이 주택임대차보호법 제4조에 의하여 2년임을 주장하나 임대인이 인정하지 아니하여 다툼이 발생함.',
#   'issues': '이 사건 계약이 재계약인지, 기간 연장 합의인지 여부',
#   'related_rules': '주택임대차보호법 제4조(임대차 기간 등)\n① 기간을 정하지 아니하거나 2년 미만으로 정한 임대차는 그 기간을 2년으로 본다. 다만, 임차인은 2년 미만으로 정한 기간이 유효함을 주장할 수 있다.',
#   'related_precedents': '',
#   'result': '임대차계약 기간을 2년으로 합의',
#   'order_text': '신청인과 피신청인은 이 사건 주택에 대한 임대차계약의 임대차기간이 2019. O. O.부터 2021. O. O.까지임을 상호 확인한다.'},
#  {'source_year': '2023',
#   'source_name': '2023년 주택·상가건물 임대차분쟁조정사례집',
#   'source_doc': '2023_주택상가건물임대차분쟁조정사례집.pdf',
#   'page_start': '28',
#   'page_end': '29',
#   'title': '원상회복 명목으로 미지급된 보증금 반환 청구',
#   'facts': '1. 신청인(종전 임차인)이 2021. O. O.경 피신청인(임대인)과 임대차보증금 550,000,000원, 임대차 기간 2021. O. O.경부터 2023. O. O.경까지로 하는 임대차계약을 체결함.\n2. 이 사건 임대차계약 종료 당시 피신청인이 화장실 욕조와 타일에 발생한 균열 등 하자에 대한 원상회복 비용을 신청인 측에서 부담해야 한다고 주장하며 임대차보증금에서 1,000,000원을 공제한 549,000,000원만 반환함.\n3. 이에 신청인이 미반환 보증금 1,000,000원을 지급받고자 조정을 신청함.',
#   'issues': '임대차보증금에서 공제되는 채무\n임차인의 원상회복의무',
#   'related_rules': '민법 제654조(준용규정)\n- 제610조제1항, 제615조 내지 제617조의 규정은 임대차에 이를 준용한다.\n민법 제615조(차주의 원상회복의무와 철거권)\n- 차주가 차용물을 반환하는 때에는 이를 원상에 회복하여야 한다. 이에 부속시킨 물건은 철거할 수 있다.',
#   'related_precedents': '임차인이 임대인에게 임대차 목적물을 반환하는 때에는 원상회복의무가 있으나 (민법 제654조, 제615조), 임차인이 통상적인 사용을 한 후에 생기는 임대차 목적물의 상태 악화나 가치의 감소를 의미하는 통상의 손모는 임대차계약의 본질상 당연하게 예정되어 있는 것이므로 별도의 특약이 없는 한 통상의 손모로 인한 부분에 대해서는 임차인이 원상회복의무를 부담하지 않음. (서울중앙지방법원 2007. 5. 31. 선고 2005가합100279 판결)\n임대차계약에 있어 임대차보증금은 임대차계약과 관련하여 발생하는 임료 상당의 부당이득반환채권 및 손해배상채권 등을 담보하는 것이므로, 임대인으로서는 임대차보증금에서 위와 같은 피담보채무를 공제한 나머지를 임차인에게 반환할 의무가 있는데, 임대차보증금에 의하여 담보되는 부당이득반환채권 및 손해배상채권의 발생에 관한 주장·증명책임은 임대인이 부담하는 것임. (대법원 1995. 7. 25. 선고 95다14664 판결)',
#   'result': '임대인이 미반환보증금에서 원상회복 비용으로 300,000원을 공제하고 나머지 금원을 임차인에게 반환하기로 합의',
#   'order_text': '신청인과 피신청인은 ○○시 ○○구 소재 주택에 관하여 2021. O. O. 당사자 간에 체결된 임대차계약과 관련하여 다음과 같이 합의한다.\n피신청인은 신청인에게 2023. O. O.까지 700,000원(미반환 보증금 1,000,000원 원상회복비용 300,000원)을 지급한다. 만일 피신청인이 이를 이행하지 아니하는 경우 다음날부터 다 갚는 날까지 미지급금에 대하여 연 5%의 비율로 계산한 돈을 가산하여 지급한다.\n피신청인이 위 제1의 가항 기재 돈의 지급을 완료하면, 신청인과 피신청인은 이 사건과 관련하여 향후 서로에 대하여 일체의 재판상, 재판외 청구 또는 이의제기를 하지 아니한다.\n피신청인은 주택임대차보호법 제26조제4항에 따라 위 제1의 가항에 기재된 사항은 강제집행 할 수 있음을 승낙한다.'},
#  {'source_year': '2023',
#   'source_name': '2023년 주택·상가건물 임대차분쟁조정사례집',
#   'source_doc': '2023_주택상가건물임대차분쟁조정사례집.pdf',
#   'page_start': '30',
#   'page_end': '31',
#   'title': '계약갱신 거절에 따른 주택 반환 청구',
#   'facts': '1. 임대인(신청인)과 임차인(피신청인) 사이에 체결된 임대차계약의 만기는 2021. 11. O.이었음.\n2. 양 당사자는 2021. 4. 26.경 임대차계약의 만기일을 2021. 11. O.로 변경하기로 하였음.\n3. 그러나 그 이후 피신청인(임차인)이 계약갱신청구권을 행사하겠다고 주장하는 한편, 신청인(임대인)은 이를 거절하였음.',
#   'issues': '임대인에게 정당한 계약갱신 거절사유가 있는지 여부',
#   'related_rules': '주택임대차보호법 제6조의3 (계약갱신 요구 등)\n① 제6조에도 불구하고 임대인은 임차인이 제6조제1항 전단의 기간 이내에 계약갱신을 요구할 경우 정당한 사유 없이 거절하지 못한다. 다만, 다음 각 호의 어느 하나에 해당하는 경우에는 그러하지 아니하다.\n8. 임대인(임대인의 직계존속·직계비속을 포함한다)이 목적 주택에 실제 거주하려는 경우',
#   'related_precedents': '',
#   'result': '임차인은 주택을 반환하고 임대인은 보증금 및 합의금을 지급하는 것으로 합의',
#   'order_text': '신청인과 피신청인은 별지 목록 기재 부동산에 관하여 2016. 11. O. 체결한 임대차계약(이하 ‘이 사건 임대차계약’이라 한다)에 관하여 다음과 같이 합의한다.\n신청인과 피신청인은, 별지 목록 부동산에 관하여 양자 간에 체결된 이 사건 임대차 계약을 2021. 11. O. 종료하기로 합의한다.\n신청인은 2021. 11. O.까지 피신청인으로부터 별지 목록 기재 부동산을 인도받음과 동시에 피신청인에게 13,000,000원(보증금 10,000,000원에 합의금 3,000,000원을 합한 금액)을 지급한다.\n신청인과 피신청인은 주택임대차보호법 제26조제4항에 따라 위 제3항에 기재된 사항에 대하여 강제집행 할 수 있음을 상호 승낙한다.'},
#  {'source_year': '2023',
#   'source_name': '2023년 주택·상가건물 임대차분쟁조정사례집',
#   'source_doc': '2023_주택상가건물임대차분쟁조정사례집.pdf',
#   'page_start': '32',
#   'page_end': '33',
#   'title': '임대차보증금 반환 시기',
#   'facts': '1. 임차인은 2020년 12월경 이 사건 주택에 관하여 보증금 370,000,000원, 임대차기간 2021년 2월경부터 2023년 2월경까지로 하는 임대차계약을 체결하였음.\n2. 임대차기간이 만료되었음에도 불구하고 임대인이 보증금을 반환하지 못하게 되자 임차인은 보증금 반환 시기를 확정하여 달라며 조정을 신청함',
#   'issues': '임대인의 보증금 반환 시기',
#   'related_rules': '',
#   'related_precedents': '부동산임대차에 있어서 임차인이 임대인에게 지급하는 보증금은 임대차관계가 종료되어 목적물을 반환하는 때까지 그 임대차관계에서 발생하는 임차인의 모든 채무를 담보하는 것으로서 임차인의 채무불이행이 없으면 그 전액을 반환하고 만약 임차인이 차임을 지급하지 아니하거나 목적물을 멸실·훼손하여 부담하는 손해배상채무 또는 임대차종료 후 목적물 반환 시까지 목적물 사용으로 인한 손해배상 내지 부당이득반환채무 등을 부담하고 있다면 임대인은 그 보증금 중에서 이를 공제하고 나머지 금액만을 반환하면 되는 것이므로 임대인의 보증금 반환의무는 임대차관계가 종료되는 경우에 그 보증금 중에서 목적물을 반환받을 때까지 생긴 연체차임 등 임차인의 모든 채무를 공제한 나머지 금액에 관하여서만 비로소 이행기에 도달하여 임차인의 목적물반환의무와 서로 동시이행의 관계에 있다. (대법원 1987. 6. 23. 선고 87다카598 판결)',
#   'result': '임대인이 후속 임차인을 구할 수 있도록 보증금 반환 시기를 3개월 연장하되, 임대주택에 대한 매매계약이 체결되는 경우에는 임대인이 연장된 반환 시기에 보증금 일부를 선지급하고, 그때부터 2개월 후 임차인으로부터 목적물을 인도받음과 동시에 나머지 보증금과 그에 대한 지연이자를 지급하기로 합의',
#   'order_text': '피신청인은 2023. 5. O.까지 신청인으로부터 임대차 목적물을 인도받음과 동시에 신청인에게 금370,000,000원을 지급한다.\n신청인은 2023. 5. O.까지 피신청인으로부터 제1항 기재 금원을 지급받음과 동시에 피신청인에게 제1항 기재 부동산을 인도한다.\n신청인과 피신청인은 위 제1항 및 제2항에도 불구하고 2023. 5. O. 이전에 별지 목록 기재 부동산에 대하여 제3자에 대한 매매계약이 체결된 경우,\n가. 피신청인은 2023. 5. O. 신청인에게 금70,000,000원을 지급한다.\n나. 피신청인은 2023. 7. O. 신청인으로부터 별지 목록 기재 부동산을 인도받음과 동시에 신청인에게 금300,000,000원 및 그에 대하여 2023. 5. O.부터 다 갚는 날까지 연 5%의 비율에 의한 이자를 지급한다.\n조정비용은 각자 부담한다.\n신청인 및 피신청인은 주택임대차보호법 제26조 제4항에 따라 제1항 내지 제3항에 기재된 사항은 강제집행할 수 있음을 상호 승낙한다.'},
#  {'source_year': '2023',
#   'source_name': '2023년 주택·상가건물 임대차분쟁조정사례집',
#   'source_doc': '2023_주택상가건물임대차분쟁조정사례집.pdf',
#   'page_start': '34',
#   'page_end': '36',
#   'title': '임차주택 벽지·소음·수압 등에 관한 수선의무',
#   'facts': '1. 임차인과 임대인은 2022년 ○월경 이 사건 주택에 대하여 임대차계약을 체결함.\n2. 임차인은 입주 직후부터 벽지, 원인불명의 소음 및 불규칙적인 수압에 관하여 임대인에게 수선을 요구하였으나 임대인이 조치를 취하지 아니하여 이 사건 주택에 관한 수선의무 이행을 청구함.',
#   'issues': '임대인의 수선의무가 존재하는지 여부\n당사자간 수선의무면제특약의 효력',
#   'related_rules': '민법 제623조(임대인의 의무)\n- 임대인은 목적물을 임차인에게 인도하고 계약존속 중 그 사용, 수익에 필요한 상태를 유지하게 할 의무를 부담한다.\n민법 제624조(임대인의 보존행위, 인용의무)\n- 임대인이 임대물의 보존에 필요한 행위를 하는 때에는 임차인은 이를 거절하지 못한다.',
#   'related_precedents': '임대인의 수선의무는 특약에 의하여 이를 면제하거나 임차인의 부담으로 돌릴 수 있으나, 그러한 특약에서 수선의무의 범위를 명시하고 있는 등의 특별한 사정이 없는 한 그러한 특약에 의하여 임대인의 수선의무를 면하거나 임차인이 그 수선의무를 부담하게 되는 것은 통상 생길 수 있는 파손의 수선 등 소규모의 수선에 한한다 할 것이고, 대표소의 수리, 건물의 주요 구성부분에 대한 대수선, 기본적 설비부분의 교체 등과 같은 대규모의 수선은 이에 포함되지 아니하고 여전히 임대인이 그 수선의무를 부담한다. (대법원 1994. 12. 9. 선고94다34692, 94다34708 판결)\n임대차계약에 있어서 임대인은 목적물을 계약 존속 중 그 사용·수익에 필요한 상태를 유지하게 할 의무를 부담하는 것이므로(민법 제623조), 목적물에 파손 또는 장애가 생긴 경우 그것이 임차인의 별 비용을 들이지 아니하고도 손쉽게 고칠 수 있을 정도의 사소한 것이어 임차인의 사용·수익을 방해할 정도의 것이 아니라면 임대인은 수선의무를 부담하지 않지만, 그것을 수선하지 아니하면 임차인이 계약에 의하여 정하여진 목적에 따라 사용·수익할 수 없는 상태로 될 정도의 것이라면 임대인은 그 수선의무를 부담한다 할 것이고, 이는 자신에게 귀책사유가 있는 임대차 목적물의 훼손의 경우에는 물론 자신에게 귀책사유가 없는 훼손의 경우에도 마찬가지라 할 것이다. (대법원 2010. 4. 29. 선고2009다96984판결)\n공사가 당초 예정된 최후의 공정까지 일이 종료되고 그 주요 구조 부분이 약정된 대로 시공되어 사회통념상 일이 완성되었고 다만 그것이 불완전하여 보수를 하여야 할 경우에는 공사가 완성되었으나 목적물에 하자가 있는 것에 지나지 아니한다고 해석함이 상당하다. (대법원 2012. 4. 13. 2011다104482, 104499 판결)',
#   'result': '임대인이 벽지 교체 비용을 부담하고, 임차인은 소음과 수압 관련 신청을 포기하되, 다만 향후 재발할 가능성을 우려하여 신청인의 요청이 있는 경우에는 임대차기간 중이라도 임대차계약을 종료할 수 있는 것으로 합의함.',
#   'order_text': '신청인과 피신청인은 2022. ○. ○. ○시 ○구 ○로, ○호(이하 ‘이 사건 주택’이라 한다)에 대하여 체결한 임대차계약(이하 ‘이 사건 임대차계약’이라 한다)에 관하여 다음과 같이 합의한다.\n피신청인은, 피신청인의 비용으로 2022. ○. ○.부터 2022. ○. ○.까지 이 사건 주택의 벽지 교체 작업을 진행한다.\n신청인은 피신청인이 위 제2항의 벽지 교체 작업을 하는 것을 수인하고 적극 협조한다.\n위 제2항에도 불구하고 신청인과 피신청인은 상호 합의에 의해 위 제2항 기재 벽지 교체 기간을 변경할 수 있다.\n신청인과 피신청인은, 신청인의 요청이 있는 때에는 이 사건 임대차계약의 기간 만료일인 2023. ○. ○.보다 앞선 날짜에 임대차계약을 종료할 수 있고, 이 경우 임대차 종료일은 당사자 합의로 정한다.\n신청인은 나머지 신청을 포기한다.'},
#  {'source_year': '2023',
#   'source_name': '2023년 주택·상가건물 임대차분쟁조정사례집',
#   'source_doc': '2023_주택상가건물임대차분쟁조정사례집.pdf',
#   'page_start': '37',
#   'page_end': '39',
#   'title': '임대차계약에 취소 사유가 존재하는지 여부',
#   'facts': '신청인(임차인)은 이 사건 임대차계약 체결 후 이 사건 주택의 실제 전용면적이 이 사건 주택에 관한 피신청인(임대인)의 광고 내용과 다른 점을 알고 피신청인에게 계약을 취소한다는 의사를 표시함으로써 당사자 간 다툼이 발생함.',
#   'issues': '임대차계약에 취소 사유가 존재하는지 여부',
#   'related_rules': '민법 제109조(착오로 인한 의사표시)\n① 의사표시는 법률행위의 내용의 중요부분에 착오가 있는 때에는 취소할 수 있다. 그러나 그 착오가 표의자의 중대한 과실로 인한 때에는 취소하지 못한다.\n② 전항의 의사표시의 취소는 선의의 제삼자에게 대항하지 못한다.\n민법 제141조(취소의 효과)\n- 취소된 법률행위는 처음부터 무효인 것으로 본다.',
#   'related_precedents': '[1] 의사표시는 법률행위 내용의 중요부분에 착오가 있는 때에는 취소할 수 있다. 법률행위 중요부분의 착오란 표의자가 그러한 착오가 없었다면 그 의사표시를 하지 않았으리라고 생각될 정도로 중요한 것이어야 하고 보통 일반인도 표의자의 처지에 있었더라면 그러한 의사표시를 하지 않았으리라고 생각될 정도로 중요한 것이어야 한다. 가령 토지의 현황과 경계에 착오가 있어 계약을 체결하기 전에 이를 알았다면 계약의 목적을 달성할 수 없음이 명백하여 계약을 체결하지 않았을 것으로 평가할 수 있을 경우에 계약의 중요부분에 관한 착오가 인정된다.\n법률행위 내용의 중요부분에 착오가 있는 때에는 그 의사표시를 취소할 수 있으나 그 착오가 표의자의 중대한 과실로 인한 때에는 취소하지 못한다. 여기서 ‘중대한 과실’이란 표의자의 직업, 행위의 종류, 목적 등에 비추어 보통 요구되는 주의를 현저히 게을리한 것을 의미한다. 토지매매에서 특별한 사정이 없는 한 매수인에게 측량을 하거나 지적도와 대조하는 등의 방법으로 매매목적물이 지적도상의 그것과 정확히 일치하는지 여부를 미리 확인하여야 할 주의의무가 있다고 볼 수 없다.\n[2] 甲이 乙로부터 토지를 매수하는 계약을 체결하면서 ‘위 토지에 인접한 매실나무 밭 바로 앞부분 약 80평이 포함되고 인접한 도로 부분 약 40평이 포함되지 않는다’고 잘못 알고 있었는데, 乙도 甲과 같이 토지의 경계를 잘못 인식하고 있어 매매계약 당시 甲에게 토지의 경계에 대하여 정확한 설명을 하지 않은 사안에서, 甲이 잘못 인식한 부분의 면적이 위 토지면적의 상당한 부분을 차지하므로, 甲은 매매계약의 목적물의 경계에 대하여 착오를 하였고, 그 착오는 중요한 부분에 해당하며, 乙 측의 잘못된 설명으로 甲의 착오가 유발되었으므로 甲의 착오에는 중대한 과실이 있다고 보기 어렵다고 한 사례(대법원 2020. 3. 26. 선고 2019다288232 판결).',
#   'result': '임대인이 임차인에게 계약금 2,000,000원 중 1,500,000원을 반환하는 것으로 합의',
#   'order_text': '피신청인은 2022. ○. ○.까지 신청인에게 금1,500,000원을 지급한다.\n만일 피신청인이 제1항 기재 돈을 지급하지 아니하면, 피신청인은 신청인에게 위 금원 중 미지급금에 대하여 2022. ○. ○.부터 다 갚는 날까지 연 5%의 비율로 계산한 돈을 가산하여 지급한다.\n위 제1항의 지급이 완료되면, 신청인과 피신청인은 신청인과 피신청인 사이에 2022. ○. ○. 서울시 ○○구 ○○로 ○, ○호에 대하여 체결된 임대차계약과 관련하여 당사자 간에 더 이상 채권·채무가 없음을 상호 확인한다.'},
#  {'source_year': '2023',
#   'source_name': '2023년 주택임대차 분쟁조정사례집',
#   'source_doc': '2023_주택임대차분쟁조정사례집.pdf',
#   'page_start': '40',
#   'page_end': '41',
#   'title': '묵시적 갱신된 임대차계약의 해지',
#   'facts': '1. 신청인은 2020. ○. ○. 피신청인과 ○○시 ○○구 소재 주택에 관하여 임대차계약을 체결함.\n2. 이 사건 임대차계약은 2022. ○. ○. 묵시적 갱신됨.\n3. 신청인이 2023. ○. ○. 피신청인에게 임대차보증금의 증액을 청구하면서 조정을 신청하였고, 조정 절차 진행 중 피신청인이 신청인에게 계약 해지를 통보함.\n4. 이에 신청인은 피신청인의 계약 해지 의사는 수용하나, 해지 의사표시가 도달된 후 3개월이 지나야 임대차계약이 종료됨을 주장하며 계약종료일에 대한 조정을 구함.',
#   'issues': '임대차계약의 묵시적 갱신 및 계약 해지',
#   'related_rules': '주택임대차보호법 제6조의2(묵시적 갱신의 경우 계약의 해지)\n① 제6조제1항에 따라 계약이 갱신된 경우 같은 조 제2항에도 불구하고 임차인은 언제든지 임대인에게 계약해지를 통지할 수 있다.\n② 제1항에 따른 해지는 임대인이 그 통지를 받은 날부터 3개월이 지나면 그 효력이 발생한다.',
#   'related_precedents': None,
#   'result': '임차인이 임대인에게 300,000원을 지급하는 조건으로 해지 의사 통지가 도달된 날부터 3개월이 되기 전에 임대차계약을 앞당겨 종료하는 것으로 조정이 성립됨.',
#   'order_text': '① 신청인과 피신청인은 별지 기재 부동산에 관하여 2020. ○. ○. 양자 간에 체결된 임대차계약을 2023. ○. ○. 종료하기로 합의한다.\n② 피신청인은 2023. ○. ○. 신청인으로부터 보증금 90,000,000원(보증금 100,000,000원에서 기반환한 10,000,000원을 제한 금액)을 반환받음과 동시에 신청인에게 별지 기재 부동산을 인도하기로 한다.\n③ 피신청인은 2023. ○. ○. 신청인에게 300,000원을 지급하기로 하되, 만일 이를 지체하는 경우 미지급금에 대하여 다음날부터 다 갚는 날까지 연 5%의 비율로 계산한 돈을 가산하여 지급한다.\n④ 신청인은 2023. ○. ○. 피신청인으로부터 별지 기재 부동산을 인도받음과 동시에 피신청인에게 보증금 90,000,000원을 반환한다.\n⑤ 신청인과 피신청인은 주택임대차보호법 제26조 제4항에 따라 위 제2 내지 4항에 기재된 사항에 대해 강제집행 할 수 있음을 상호 승낙한다.'},
#  {'source_year': '2023',
#   'source_name': '2023년 주택임대차 분쟁조정사례집',
#   'source_doc': '2023_주택임대차분쟁조정사례집.pdf',
#   'page_start': '42',
#   'page_end': '44',
#   'title': '계약갱신여부 및 임대차계약 종료일 확인',
#   'facts': '1. 임대인과 임차인은 2017. ○. ○. 이 사건 주택에 관하여 임차보증금 400,000,000원, 임대차기간 2017. ○. ○.부터 2019. ○. ○.(24개월)까지로 정하여 최초 임대차계약을 체결하였음.\n2. 이후 임대인과 임차인은 2019년 ○월경(1차 재계약), 2020년 ○월경 재계약(2차 재계약)을 체결하였고 2021. ○. ○. 2차 재계약과 동일한 조건으로 재계약(이 사건 임대차계약)을 체결하면서 임대차계약 기간만료일을 특정하지 않았음.\n3. 임대인은 임차인에게 이 사건 임대차계약의 기간만료일을 이 사건 임대차시일로부터 2년이 되는 2023. ○. ○.자에 이 사건 주택을 반환하여 줄 것을 요구하였으나 임차인과 임대차계약의 종료일에 관해 이견이 발생하여 분쟁이 발생하자 이 사건 조정을 신청함.',
#   'issues': '이 사건 2차 재계약 및 이 사건 임대차계약의 존부\n기간을 정하지 아니한 임대차의 임대차기간\n임차인의 계약갱신요구권 행사 여부',
#   'related_rules': '주택임대차보호법 제6조(계약의 갱신)\n① 임대인이 임대차기간이 끝나기 6개월 전부터 2개월 전까지의 기간에 임차인에게 갱신거절의 통지를 하지 아니하거나 계약조건을 변경하지 아니하면 갱신하지 아니한다는 뜻의 통지를 하지 아니한 경우에는 그 기간이 끝난 때에 전 임대차와 동일한 조건으로 다시 임대차한 것으로 본다. 임차인이 임대차기간이 끝나기 2개월 전까지 통지하지 아니한 경우에도 또한 같다.\n② 제1항의 경우 임대차의 존속기간은 2년으로 본다.\n③ 2기의 차임액(借賃額)에 달하도록 연체하거나 그 밖에 임차인으로서의 의무를 현저히 위반한 임차인에 대하여는 제1항을 적용하지 아니한다.\n주택임대차보호법 제6조의3(계약갱신 요구 등)\n① 제6조에도 불구하고 임대인은 임차인이 제6조제1항 전단의 기간 이내에 계약갱신을 요구할 경우 정당한 사유 없이 거절하지 못한다. 다만, 다음 각 호의 어느 하나에 해당하는 경우에는 그러하지 아니하다.\n③ 갱신되는 임대차는 전 임대차와 동일한 조건으로 다시 계약된 것으로 본다. 다만, 차임과 보증금은 제7조의 범위에서 증감할 수 있다.\n주택임대차보호법 제4조(임대차기간 등)\n① 기간을 정하지 아니하거나 2년 미만으로 정한 임대차는 그 기간을 2년으로 본다. 다만, 임차인은 2년 미만으로 정한 기간이 유효함을 주장할 수 있다.\n주택임대차보호법 제7조(차임증감청구권)\n② 제1항에 따른 증액청구는 약정한 차임이나 보증금의 20분의 1 금액을 초과하지 못한다.',
#   'related_precedents': None,
#   'result': '이 사건 임대차계약의 기간만료일은 2023. ○. ○.임을 확인하되, 임차인의 계약갱신요구를 받아들여 월차임을 5% 증액하고 임대차기간을 임차인이 원하는 기간으로 하여 갱신하는 것으로 양 당사자 간 합의',
#   'order_text': '① 신청인과 피신청인은 이 사건 주택에 대하여 2017. ○. ○. 최초 체결된 후 2019. ○. ○, 2020. ○. ○, 2021. ○. ○. 갱신된 임대차계약(이하 ‘이 사건 임대차계약’이라 한다)에 관하여 다음과 같이 합의한다.\n② 신청인과 피신청인은, 이 사건 임대차계약의 기간만료일이 2023. ○. ○.임을 상호 확인한다.\n③ 신청인과 피신청인은, 피신청인의 계약갱신요구에 의해 이 사건 임대차계약이 2023. ○. ○. 갱신됨을 상호 확인한다.\n④ 신청인과 피신청인은, 위 제3항 기재 갱신되는 임대차계약의 월차임을 이 사건 임대차계약의 월차임 1,400,000원(매월 후불로 지급)에서 70,000원을 증액한 1,470,000원(매월 후불로 지급)으로, 임대차기간을 2023. ○. ○.부터 2023. ○. ○.까지로 한다.\n⑤ 신청인은 2023. ○. ○. 피신청인으로부터 별지 목록 기재 부동산을 인도받음과 동시에 피신청인에게 임차보증금 400,000,000원을 지급한다.\n⑥ 피신청인은 2023. ○. ○. 신청인으로부터 임차보증금 400,000,000원을 지급받음과 동시에 신청인에게 별지 목록 기재 부동산을 인도한다.\n⑦ 신청인과 피신청인은, 위 제3항 기재 갱신되는 임대차계약의 그 밖의 나머지 계약조건에 대하여 제4항, 제5항, 제6항의 기재내용을 제외하고는 이 사건 임대차계약에서 정한 내용이 그대로 유지됨을 확인한다.\n⑧ 신청인과 피신청인은, 주택임대차보호법 제26조 제4항에 따라 위 제5항 및 제6항에 기재된 사항에 대하여 강제집행을 할 수 있음을 상호 승낙한다.'},
#  {'source_year': '2023',
#   'source_name': '2023년 주택임대차 분쟁조정사례집',
#   'source_doc': '2023_주택임대차분쟁조정사례집.pdf',
#   'page_start': '45',
#   'page_end': '46',
#   'title': '계약갱신 거절사유 존부 및 손해배상의 예정',
#   'facts': '1. 임차인은 2019. 3월경 임대인과 이 사건 아파트에 관하여 채권적 전세계약을 체결함.\n2. 전세계약 만료 2개월 전 임차인이 임대인에게 계약갱신요구권을 행사하였으나, 임대인이 실거주를 이유로 계약갱신을 거절함.',
#   'issues': '임대인이 실거주를 이유로 임차인의 계약갱신요구권 행사에 대한 갱신거절 시, 임대인의 실거주 주장만으로 적법하게 거절한 것으로 볼 수 있는지 여부\n임대인이 실거주하지 않을 경우를 대비하여 이에 대한 임대인과 임차인 사이의 손해배상예정액 합의가 가능한지 여부',
#   'related_rules': '주택임대차보호법 제6조의3(계약갱신 요구 등)\n① 제6조에도 불구하고 임대인은 임차인이 제6조제1항 전단의 기간 이내에 계약갱신을 요구할 경우 정당한 사유 없이 거절하지 못한다. 다만, 다음 각 호의 어느 하나에 해당하는 경우에는 그러하지 아니하다.\n8. 임대인(임대인의 직계존속·직계비속을 포함한다)이 목적 주택에 실제 거주하려는 경우\n⑤ 임대인이 제1항제8호(실거주)의 사유로 갱신을 거절하였음에도 불구하고 갱신요구가 거절되지 아니하였더라면 갱신되었을 기간이 만료되기 전에 정당한 사유 없이 제3자에게 목적 주택을 임대한 경우 임대인은 갱신거절로 인하여 임차인이 입은 손해를 배상하여야 한다.\n(참고) 국토교통부 법무부 귀 주택임대차보호법 해설집 31면\n- 임대인이 위 주택임대차보호법 규정되어 있는 정당한 사유 없이 제3자에게 임대하는 것 이외에 주택을 제3자에게 매매하거나 공실로 두는 등 실제로는 거주의사 없이 허위로 임차인의 계약갱신요구를 거절한 것으로 판단된 경우에는 임대인은 임차인에게 민법 제750조 일반불법행위책임을 지게 될 수 있음.\n민법 제398조 (배상액의 예정)\n① 당사자는 채무불이행에 관한 손해배상액을 예정할 수 있다.',
#   'related_precedents': None,
#   'result': '실거주를 하지 않을 경우 손해배상액 20,000,000원을 지급하기로 합의',
#   'order_text': '① 신청인은 2021. 5. ○. 피신청인 △△△, ☆☆☆으로부터 공동하여 금190,000,000원(보증금)을 지급받음과 동시에, 피신청인 △△△, ☆☆☆에게 별지 목록 기재 부동산을 인도한다.\n② 피신청인 △△△, ☆☆☆은 2021. 5. ○. 신청인으로부터 제1항 기재 부동산을 인도받음과 동시에, 신청인에게 공동하여 금190,000,000원(보증금)을 지급한다.\n③ 신청인과 피신청인 △△△, ☆☆☆ 사이에 별지 목록 기재 부동산에 관하여 2019. 3. ○. 체결된 전세계약은 주택임대차보호법 제6조의3 제1항제8호의 사유로 갱신되지 아니함을 상호 확인한다. 단, 피신청인 △△△, ☆☆☆이 2019. 5. ○.부터 2023. 3. ○.까지 주택임대차보호법 제6조의3제1항제8호 사유가 존재하지 아니하여 신청인이 피신청인 △△△, ☆☆☆에게 손해배상을 청구하는 경우 손해배상액은 금20,000,000원으로 한다.\n④ 신청인의 나머지 신청은 포기한다.\n⑤ 신청인과 피신청인 △△△, ☆☆☆은 주택임대차보호법 제26조 제4항에 따라 위 제1항, 제2항에 기재된 사항에 대하여 강제집행을 할 수 있음을 상호 승낙한다.'},
#  {'source_year': '2023',
#   'source_name': '2023년 주택임대차 분쟁조정사례집',
#   'source_doc': '2023_주택임대차분쟁조정사례집.pdf',
#   'page_start': '48',
#   'page_end': '50',
#   'title': '실거주 사유로 갱신거절 후 제3자에게 임대',
#   'facts': '1. 신청인(종전 임차인)은 2020. 5.경 신청외인(종전임대인)과 보증금 220,000,000원, 월 차임 400,000원, 임대차기간 2020. ○.경부터 2022. ○.경까지로 하는 임대차계약을 체결하였고, 피신청인(임대인)은 신청외인과 이 사건 주택에 관한 매매계약을 체결한 후 소유권이전등기를 경료함으로써 임대인 지위를 승계함.\n2. 신청인이 2022. 2.경 피신청인에게 문자와 유선통화를 통해 피신청인에게 계약갱신을 원한다는 취지의 의사를 표시하였음에도 불구하고, 피신청인이 본인 및 직계존속의 실거주를 이유로 이를 거절함에 따라, 당초 계약 만료일보다 앞선 2022. 5.경 계약을 종료하기로 합의함.\n3. 이 사건 임대차계약 종료 이후 신청인이 확정일자 부여현황 발급을 통해 피신청인이 2022. ○.경 제3자에게 이 사건 주택을 보증금 40,000,000원, 월 차임 1,800,000원에 임대한 사실을 확인함에 따라 그로 인한 손해배상을 구하고자 본건 조정을 신청함.',
#   'issues': '주택임대차보호법 제6조의3제5항 손해배상책임',
#   'related_rules': '주택임대차보호법 제6조의3(계약갱신 요구 등)\n① 제6조에도 불구하고 임대인은 임차인이 제6조제1항 전단의 기간 이내에 계약갱신을 요구할 경우 정당한 사유 없이 거절하지 못한다. 다만, 다음 각 호의 어느 하나에 해당하는 경우에는 그러하지 아니하다.\n8. 임대인(임대인의 직계존속·직계비속을 포함한다)이 목적 주택에 실제 거주하려는 경우\n⑤ 임대인이 제1항제8호의 사유로 갱신을 거절하였음에도 불구하고 갱신요구가 거절되지 아니하였더라면 갱신되었을 기간이 만료되기 전에 정당한 사유 없이 제3자에게 목적 주택을 임대한 경우 임대인은 갱신거절로 인하여 임차인이 입은 손해를 배상하여야 한다.\n⑥ 제5항에 따른 손해배상액은 거절 당시 당사자 간에 손해배상액의 예정에 관한 합의가 이루어지지 않는 한 다음 각 호의 금액 중 큰 금액으로 한다.\n1. 갱신거절 당시 월차임(차임 외에 보증금이 있는 경우에는 그 보증금을 제7조의2 각 호 중 낮은 비율에 따라 월 단위의 차임으로 전환한 금액을 포함한다. 이하 "환산월차임"이라 한다)의 3개월분에 해당하는 금액\n2. 임대인이 제3자에게 임대하여 얻은 환산월차임과 갱신거절 당시 환산월차임 간 차액의 2년분에 해당하는 금액\n3. 제1항제8호의 사유로 인한 갱신거절로 인하여 임차인이 입은 손해액',
#   'related_precedents': '임차인의 계약갱신요구는 상대방 있는 의사표시이므로 반드시 명시적일 필요는 없고 묵시적으로 표시되어 계약갱신요구 기간 내 임대인에게 도달하면 족하다. (서울중앙지방법원 2023. 1. 26. 선고 2022가단6858 판결)\n주택임대차보호법 제6조의3제5항 소정 “정당한 사유”는 갱신거절 당시 예측할 수 없던 사정, 예컨대 실거주를 하던 직계존속이 갑자기 사망한 경우, 실거주 중 갑자기 해외 주재원으로 파견되는 경우 등을 의미한다. (서울중앙지방법원 2022. 10. 18. 선고 2022가소1067836 판결)',
#   'result': '피신청인(임대인)이 신청인(임차인)에게 주택임대차보호법상 법정 손해배상액보다 감액된 8,490,000원을 2회에 걸쳐 분할 배상하는 것으로 조정이 성립됨.',
#   'order_text': '① 신청인과 피신청인은 인천 ○○구 ○○동 소재 주택에 관하여 2020. ○○. ○○. 당사자 간에 체결된 임대차계약이 2022. ○. ○○. 종료되었음을 확인한다.\n② 피신청인은 위 제1항 기재 임대차계약과 관련하여 신청인에게 2023. ○. ○.까지 5,000,000원을, 2023. ○. ○.까지 3,490,000원을 각 지급하기로 한다. 만일 피신청인이 이를 지체하는 경우 각 지급일 다음날부터 다 갚는 날까지 미지급금에 대하여 연 8%의 비율로 계산한 돈을 가산하여 지급한다.\n③ 피신청인이 위 제2항 기재 돈의 지급을 완료하면, 신청인과 피신청인은 이 사건 신청원인과 관련하여 향후 서로에 대하여 일체의 재판상, 재판외 청구 또는 이의제기를 하지 아니한다.\n④ 피신청인은 주택임대차보호법 제26조 제4항에 따라 위 제2항에 기재된 사항은 강제집행 할 수 있음을 승낙한다.'},
#  {'source_year': '2023',
#   'source_name': '2023년 주택임대차 분쟁조정사례집',
#   'source_doc': '2023_주택임대차분쟁조정사례집.pdf',
#   'page_start': '51',
#   'page_end': '52',
#   'title': '실거주 사유로 갱신거절 후 제3자에게 매도',
#   'facts': '1. 신청인(종전 임차인)은 2020. 1.경 피신청인(임대인)과 보증금 240,000,000원, 임대차기간 2020. ○.경부터 2022. ○.경까지로 하는 임대차계약을 체결함.\n2. 신청인이 계약갱신요구 가능기간 내에 피신청인에게 계약갱신을 요구하였으나, 피신청인은 본인 내지 직계가족의 실거주를 이유로 이를 거절함.\n3. 이에 신청인은 피신청인과 이 사건 임대차계약을 당초 계약기간만료일보다 앞서 종료하기로 합의하였고, 2021. ○.경 피신청인에게 주택을 인도하고 보증금을 반환받음.\n4. 그 후 피신청인이 이 사건 주택을 제3자에게 매도한 사실을 확인하게 된 신청인이 그로 인한 손해배상을 구하고자 조정을 신청함.',
#   'issues': '민법 제750조 소정 손해배상책임의 발생 및 범위',
#   'related_rules': '주택임대차보호법 제6조의3(계약갱신 요구 등)\n① 제6조에도 불구하고 임대인은 임차인이 제6조제1항 전단의 기간 이내에 계약갱신을 요구할 경우 정당한 사유 없이 거절하지 못한다. 다만, 다음 각 호의 어느 하나에 해당하는 경우에는 그러하지 아니하다.\n8. 임대인(임대인의 직계존속·직계비속을 포함한다)이 목적 주택에 실제 거주하려는 경우\n민법 제750조(불법행위의 내용)\n- 고의 또는 과실로 인한 위법행위로 타인에게 손해를 가한 자는 그 손해를 배상할 책임이 있다.',
#   'related_precedents': '임대인은 주택임대차보호법 제6조의3 제1항 각호에 해당하는 사유가 있어야 임차인의 계약갱신 요구를 거절할 수 있으나, 적법한 근거 없이 갱신거절을 함으로써 임차인이 임차목적물을 사용·수익하지 못하게 하는 것은 임차인의 임차권을 침해하는 불법행위에 해당한다. (수원지방법원안양지원 2022. 11. 11. 선고 2021가단108009 판결)\n위와 같은 경우의 통상손해는 ‘이 사건 임대차계약이 임차인의 갱신요구에 따라 갱신되었을 경우 예상되는 1/20 증액된 보증금과 임차인이 이 사건 임대차계약이 종료될 무렵 이 사건 주택과 유사한 입지조건을 가진 이사 후 주택을 임차하는 데 필요했던 보증금과의 차액에 관한 2년간의 대출이자 상당액’이라 할 것이다. (수원지방법원안양지원 2022. 11. 11. 선고 2021가단108009 판결)\n한편, 위와 같은 경우의 통상손해를 ① 중개수수료 및 이사비와 ② 임차인이 신규 임대차계약을 체결한 것에 대해 민사소송법 제202조의 2에 따라 산정한 손해액으로 계산한 하급심 판례도 있다. (서울중앙지방법원 2022. 12. 14. 선고 2022가단5113218판결)',
#   'result': '피신청인(임대인)이 신청인(임차인)에게 손해배상으로 2,000,000원을 지급하는 것으로 조정이 성립됨.',
#   'order_text': '① 신청인과 피신청인은 ○○시 ○○구 소재 주택에 관하여 2020. ○. ○. 양 당사자 간 체결된 임대차계약과 관련하여 다음과 같이 합의한다.\n② 피신청인은 신청인에게 2023. ○. ○.까지 2,000,000원을 지급한다. 만일 이를 지체하는 경우 미지급금에 대하여 다음날부터 다 갚는 날까지 연 5%의 비율로 계산한 돈을 가산하여 지급한다.\n③ 피신청인이 위 제2항 기재 돈을 모두 지급하면, 신청인과 피신청인은 이 사건 신청원인과 관련하여 향후 일체의 재판상, 재판외 청구 또는 이의제기를 하지 아니한다.\n④ 피신청인은 주택임대차보호법 제26조제4항에 따라 위 제2항에 기재된 사항은 강제집행 할 수 있음을 승낙한다.'},
#  {'source_year': '2023',
#   'source_name': '2023년 주택임대차 분쟁조정사례집',
#   'source_doc': '2023_주택임대차분쟁조정사례집.pdf',
#   'page_start': '53',
#   'page_end': '55',
#   'title': '원상회복의무의 존부 및 그 범위',
#   'facts': '1. 임대인들과 임차인(전대인)은 2020년 3월경 이 사건 주택에 관하여 전차인을 입주자로 정하여 임대차계약을 체결하고, 전차인으로 하여금 보증금 중 일부를 부담하게 한 뒤 이 사건 주택에 거주하도록 하였음.\n2. 이 사건 계약은 한 차례 묵시적으로 갱신된 후, 당사자들 간의 합의에 의하여 2023년 5월경 종료되었음.\n3. 임대인들과 임차인은 임차보증금 반환에 있어 전차인이 부담한 보증금은 임대인들이 전차인에게 직접 지급하기로 약정하였음.\n4. 임대인들이 전차인에게 직접 지급하기로 한 보증금 반환에 있어 원상회복비용을 공제하고자 하여 임대인들과 전차인 사이에 원상회복 범위 및 비용에 관하여 분쟁이 발생함.',
#   'issues': '원상회복의무의 존부 및 그 범위',
#   'related_rules': '민법 제615조 (차주의 원상회복의무 철거권)\n- 차주가 사용물을 반환하는 때에는 이를 원상에 회복하여야 한다. 이에 부속시킨 물건은 철거할 수 있다.\n민법 제654조 (준용규정)\n- 제610조제1항, 제615조 내지 제617조의 규정은 임대차에 이를 준용한다.',
#   'related_precedents': '임차인은 임대차계약이 종료한 경우에는 임차목적물을 원상에 회복하여 임대인에게 반환할 의무가 있는데, 원상으로 회복한다고 함은 사회통념상 통상적인 방법으로 사용·수익을 하여 그렇게 될 것이 상대로서, 사용을 개시할 당시의 상태보다 나빠지더라도 그대로 반환하면 무방하다는 것으로, 임차인이 통상적인 사용을 한 후에 생기는 임차목적물의 상태 악화나 가치의 감소를 의미하는 통상의 손모(損耗)에 관하여는 임차인의 과책사유가 없으므로 그 원상회복비용은 채권법의 일반원칙에 비추어 특약이 없는 한 임대인이 부담한다고 하여야 한다. 즉, 임대차계약은 임차인에 의한 임차목적물의 사용과 그 대가로서 임료의 지급을 내용으로 하는 것이고, 임차목적물의 손모의 발생은 임대차라고 하는 계약의 본질상 당연하게 예정되어 있다. 이와 같은 이유로 건물의 임대차에서는 임차인이 사회통념상 통상적으로 사용한 경우에 생기는 임차목적물의 상태가 나빠지거나 또는 가치 감소를 의미하는 통상적인 손모에 관한 투자자의 감가는 일반적으로 임대인이 감가상각비나 수선비 등의 필요경비 상당을 임료에 포함시켜 이를 지급받음으로써 회수하고 있다. 따라서 건물의 임대차에서 생기는 통상의 손모에 관해 원상회복의무를 부담시키는 것은 임차인에게 예상하지 않은 특별한 부담을 지우는 것이 되므로 임차인에게 그와 같은 원상회복의무를 부담시키기 위해서는 적어도 임차인이 원상회복을 위해 그 보수비용을 부담하게 되는 손모의 범위가 임대차계약서의 조항 자체에서 구체적으로 명시되어 있거나 그렇지 아니하고 임대차계약서에서 분명하지 않은 경우에는 임대인이 말로써 임차인에게 설명하여 임차인이 그 취지를 분명하게 인식하고 그것을 합의의 내용으로 하였다고 인정되는 등 그와 같은 취지의 특약이 명확하게 합의되어 있어야 할 필요가 있다고 해석함이 상당하다. (서울중앙지법 2007. 5. 31. 선고 2005가합100279판결)',
#   'result': '전차인이 도배 및 장판비용의 일부를 부담하는 것으로 합의',
#   'order_text': '① 신청인들과 피신청인은, 2020. ○. ○. ○○시 ○○구 ○○번길, ○층(이하 ‘이 사건 주택’이라 한다)에 대하여 신청인들을 임대인으로, 조정 외 ○○을 임차인으로, 피신청인을 입주자로 하여 체결한 임대차계약(이하 ‘이 사건 임대차계약’이라 한다)에 관하여 다음과 같이 합의한다.\n② 피신청인은 신청인들에게 이 사건 임대차계약에 기한 원상회복비용으로 750,000원을 부담한다.\n③ 신청인들은 공동하여 2023. ○. ○.까지 피신청인에게 2,417,259원(미반환 임차보증금 3,300,000원에서 위 제2항 기재 원상회복비용 750,000원과 미납 차임 73,326원 및 미납 수도세 59,415원을 공제한 금액)을 지급한다. 만일 이를 지체하는 경우 신청인들은 공동하여 피신청인에게 위 돈 중 미지급한 돈에 대하여 2023. ○. ○.부터 다 갚는 날까지 연 5%의 비율로 계산한 돈을 가산하여 지급한다.\n④ 위 제3항의 이행이 완료되면, 신청인들과 피신청인은 이 사건 임대차계약과 관련하여 상호 간에 더 이상 채권·채무가 없음을 확인한다.\n⑤ 신청인들은 주택임대차보호법 제26조 제4항에 따라 위 제3항에 기재된 사항에 대하여 강제집행할 수 있음을 승낙한다.'},
#  {'source_year': '2023',
#   'source_name': '2023년 주택임대차 분쟁조정사례집',
#   'source_doc': '2023_주택임대차분쟁조정사례집.pdf',
#   'page_start': '56',
#   'page_end': '59',
#   'title': '중개보수 부담 주체',
#   'facts': '1. 임차인은 2019. ○. ○. 임대인과 이 사건 주택에 관하여 임대차기간 2019. ○. ○.부터 2021. ○. ○.(24개월)까지로 하는 임대차계약을 체결하였음.\n2. 임차인과 임대인은 2021. ○. ○. 임차인의 계약갱신요구에 의해 이 사건 임대차계약을 갱신하되, 임대차기간을 2021. ○. ○.부터 2023. ○. ○.까지로 정함.\n3. 이후 임차인은 이 사건 갱신된 임대차계약의 임대차기간 중인 2022. ○. ○.에 임대인에게 2022. ○. ○. 이사하겠다는 취지로 계약해지를 통지하여 그 무렵 임대인에게 도달하였고 임대인은 이에 동의의 의사를 표시함.\n4. 같은 날 임대인은 임차인에게 이 사건 주택에 관한 임대인과 신규 임차인 사이의 임대차계약에 따른 중개보수는 임차인이 부담해야 함을 통지하였고 임차인은 이에 대해 현 보증금에 대해서만 지불하면 된다고 질의함.\n5. 이후 임대인은 2022. ○. ○. 이 사건 주택에 관하여 조정 외 제3자와 새로이 임대차계약을 체결하였고 임차인은 2022. ○. ○. 임대인에게 이 사건 주택을 인도하기로 함.\n6. 임대인은 2022. ○. ○. 임차인에게 사전에 합의된대로 중개보수를 부담할 것을 통지함.\n7. 이에 임차인은 임대인과 새로운 임차인 사이의 임대차계약에 따른 중개보수 부담 주체에 대한 확인을 구하고자 조정을 신청함.',
#   'issues': '이 사건 임대차계약이 합의해지된 것인지, 해지권 행사에 따라 해지된 것인지 여부 및 그에 따른 중개보수 부담 주체\n임차인과 임대인 간 중개보수 부담 합의 성부',
#   'related_rules': '주택임대차보호법 제6조의2(묵시적 갱신의 경우 계약의 해지)\n① 제6조제1항에 따라 계약이 갱신된 경우 같은 조 제2항에도 불구하고 임차인은 언제든지 임대인에게 계약해지(契約解除)를 통지할 수 있다.\n② 제1항에 따른 해지는 임대인이 그 통지를 받은 날부터 3개월이 지나면 그 효력이 발생한다.\n주택임대차보호법 제6조의3(계약갱신 요구 등)\n① 제6조에도 불구하고 임대인은 임차인이 제6조제1항 전단의 기간 이내에 계약갱신을 요구할 경우 정당한 사유 없이 거절하지 못한다.\n② 임차인은 제1항에 따른 계약갱신요구권을 1회에 한하여 행사할 수 있다. 이 경우 갱신되는 임대차의 존속기간은 2년으로 본다.\n③ 갱신되는 임대차는 전 임대차와 동일한 조건으로 다시 계약된 것으로 본다. 다만, 차임과 보증금은 제7조의 범위에서 증감할 수 있다.\n④ 제1항에 따라 갱신되는 임대차의 해지에 관하여는 제6조의2를 준용한다.\n민법 제109조(착오로 인한 의사표시)\n① 의사표시는 법률행위의 내용의 중요부분에 착오가 있는 때에는 취소할 수 있다. 그러나 그 착오가 표의자의 중대한 과실로 인한 때에는 취소하지 못한다.\n공인중개사법 제32조(중개보수 등)\n① 개업공인중개사는 중개업무에 관하여 중개의뢰인으로부터 소정의 보수를 받는다.',
#   'related_precedents': '계약이 성립하기 위해서는 당사자 사이에 계약의 내용에 관한 의사의 합치가 있어야 한다. 이러한 의사의 합치는 계약의 내용을 이루는 모든 사항에 관하여 있어야 하는 것은 아니고, 본질적 사항이나 중요 사항에 관하여 구체적으로 의사가 합치되거나 적어도 장래 구체적으로 특정할 수 있는 기준과 방법 등에 관하여 합의가 있으면 충분하다. 한편 당사자가 의사의 합치가 이루어져야 한다고 표시한 사항에 대하여 합의가 이루어지지 않은 경우에는 특별한 사정이 없는 한 계약은 성립하지 않은 것으로 보는 것이 타당하다. (대법원 2017. 5. 30. 선고, 2015다34437 판결)\n임대인이 신규 임차인과 임대차계약을 맺으면서 지출한 중개료는 기존 임차인이 부담하기로 하는 특별한 약정이 없는 한 기존 임차인이 부담할 성질의 것이 아니므로 이를 공제한 것은 잘못된 것이다. 임차인이 임대차기간 종료 전에 퇴거하더라도 어차피 임대인은 임대차계약이 정상 종료된 경우 신규 임차인과의 계약 체결 위해 중개료 지출해야 할 것이니 중도퇴거를 사유로 중개료를 임차인이 부담한다고 볼 수 없다. (서울중앙지방법원, 1998. 7. 1. 선고 97나55316 판결)\n의사표시는 법률행위의 내용의 중요부분에 착오가 있는 때에는 취소할 수 있다. 법률행위의 중요부분의 착오란 표의자가 그러한 착오가 없었더라면 그 의사표시를 하지 않았으리라고 생각될 정도로 중요한 것이어야 하고 보통 일반인도 표의자의 처지에 있었다면 그러한 의사표시를 하지 않았으리라고 생각될 정도로 중요한 것이어야 한다. (대법원 2019다288232, 2020. 3. 26. 판결)\n동기의 착오가 법률행위의 내용의 중요 부분의 착오에 해당함을 이유로 표의자가 법률행위를 취소하려면 그 동기를 당해 의사표시의 내용으로 삼을 것을 상대방에게 표시하고 의사표시의 해석상 법률행위의 내용으로 되어 있다고 인정되면 충분하고 당사자들 사이에 별도로 그 동기를 의사표시의 내용으로 삼기로 하는 합의까지 이루어질 필요는 없지만, 그 법률행위의 내용의 착오는 보통 일반인이 표의자의 입장에 섰다면 그와 같은 의사표시를 하지 아니하였으리라고 여겨질 정도로 그 착오가 중요한 부분에 관한 것이어야 한다. (대법원 97다26210, 1997. 9. 30. 판결)',
#   'result': '임대인이 부담한 중개보수 중 1/2을 임차인이 지급하는 것으로 조정안을 제시하였고 당사자 모두 조정안을 수락하여 동일 내용으로 합의가 성립함.',
#   'order_text': '① 신청인은 2022. ○. ○.까지 피신청인에게 금742,000원(피신청인과 조정 외 제3자 사이에 체결한 임대차계약에 따른 중개보수(부가세 포함) 1,485,000원의 1/2에 해당하는 금액)을 지급한다.\n② 신청인이 제1항 기재 돈을 지급하지 아니하면, 신청인은 피신청인에게 위 돈 중 미지급한 돈에 대하여 2022. ○. ○.부터 다 갚는 날까지 연 5%의 비율에 해당하는 금원을 가산하여 지급한다.\n③ 신청인과 피신청인은 위 제1항의 이행이 완료되면, 피신청인과 2022. ○. ○. 조정 외 ○○○ 사이에 ○○시 ○○구 ○○동 100, ○○아파트 ○동 ○호에 대하여 체결된 임대차계약에 따른 중개보수와 관련하여 당사자 사이에 더 이상의 채권·채무 관계가 없음을 확인한다.\n④ 신청인은 주택임대차보호법 제26조제4항에 따라 제1항, 제2항에 기재된 사항에 대하여 강제집행 할 수 있음을 승낙한다.'}]

# %%
len(a)
# Out:
# 14
